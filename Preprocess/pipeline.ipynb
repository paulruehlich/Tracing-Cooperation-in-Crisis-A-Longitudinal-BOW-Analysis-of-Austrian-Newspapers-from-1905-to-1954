# %%
import pandas as pd
import re
import nltk
import spacy
from nltk.corpus import stopwords
from num2words import num2words

# Einmalig notwendige Downloads
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("punkt_tab")

# Stopwörter und SpaCy Modell
stop_words = set(stopwords.words("german"))
nlp = spacy.load("de_core_news_sm")
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
def clean_url(text):
    return re.sub(r"http\S+", "", text)

def fix_contraction(text):
    return text  # aktuell leer, da keine deutschen Kontraktionen im Einsatz

def clean_non_alphanumeric(text):
    return re.sub(r"[^a-zA-Z0-9äöüÄÖÜß]", " ", text)

def clean_lowercase(text):
    return str(text).lower()

def clean_tokenization(text):
    return nltk.word_tokenize(text, language="german")

def clean_stopwords(tokens):
    return [word for word in tokens if word not in stop_words]

def numbers_to_words(tokens):
    output = []
    for token in tokens:
        if token.isnumeric():
            try:
                output.append(num2words(token, lang="de"))
            except:
                output.append(token)
        else:
            output.append(token)
    return output

def clean_lemmatization(tokens):
    doc = nlp(" ".join(tokens))
    return [token.lemma_ for token in doc]

def clean_length(tokens):
    return [word for word in tokens if len(word) > 2]

def count_word_frequencies(tokens):
    freq = nltk.FreqDist(tokens)
    return [(word, count / len(tokens)) for word, count in freq.most_common()]

def convert_to_string(tokens):
    return " ".join(tokens)

def pre_processing_pipeline(text):
    try:
        if pd.isna(text):
            return "", [], []
        text = clean_url(text)
        text = fix_contraction(text)
        text = clean_non_alphanumeric(text)
        text = clean_lowercase(text)
        tokens = clean_tokenization(text)
        tokens = numbers_to_words(tokens)
        tokens = clean_stopwords(tokens)
        tokens = clean_lemmatization(tokens)
        tokens = clean_length(tokens)
        freqs = count_word_frequencies(tokens)
        final = convert_to_string(tokens)
        return final, tokens, freqs
    except Exception as e:
        print("❌ Fehler bei Text:", "→", e)
        return "", [], []

# %%
import os
import pandas as pd
from multiprocessing import Pool

# 📁 Eingabe- und Ausgabeordner
input_folder = "splits_small"
output_folder = "results"
os.makedirs(output_folder, exist_ok=True)

# 📄 Alle CSV-Dateien im Eingabeordner sammeln
csv_files = sorted([
    f for f in os.listdir(input_folder)
    if f.endswith(".csv")
])

# 🔧 Funktion zur Verarbeitung einzelner Dateien
def process_single_file(file):
    path = os.path.join(input_folder, file)
    print(f"🚀 Starte Datei: {file}")  # Live-Feedback beim Start

    try:
        df = pd.read_csv(path)
        if "text" not in df.columns:
            print(f"❌ Spalte 'text' fehlt in {file}")
            return

        results = df["text"].apply(pre_processing_pipeline)
        df["processed_text"] = results.apply(lambda x: x[0])
        df["tokens"] = results.apply(lambda x: x[1])
        df["freqs"] = results.apply(lambda x: x[2])

        out_path = os.path.join(output_folder, file.replace(".csv", "_processed.csv"))
        df.to_csv(out_path, index=False)
        print(f"✅ Gespeichert: {out_path}")
    except Exception as e:
        print(f"💥 Fehler bei {file}: {e}")

# 🚀 Parallele Verarbeitung starten
if __name__ == "__main__":
    with Pool(processes=15) as pool:
        pool.map(process_single_file, csv_files)
# Out:
# 🚀 Starte Datei: split_10_part14.csv🚀 Starte Datei: split_10_part4.csv🚀 Starte Datei: split_10_part1.csv🚀 Starte Datei: split_11_part13.csv🚀 Starte Datei: split_10_part9.csv🚀 Starte Datei: split_11_part18.csv
# 🚀 Starte Datei: split_11_part5.csv🚀 Starte Datei: split_12_part1.csv
# 🚀 Starte Datei: split_12_part3.csv🚀 Starte Datei: split_12_part8.csv
# 🚀 Starte Datei: split_13_part12.csv
# 🚀 Starte Datei: split_13_part4.csv
#
# 🚀 Starte Datei: split_13_part9.csv
# 🚀 Starte Datei: split_14_part5.csv🚀 Starte Datei: split_14_part13.csv
#
#
#
#
#
#
#
# ✅ Gespeichert: results/split_10_part14_processed.csv
# 🚀 Starte Datei: split_10_part15.csv
# ✅ Gespeichert: results/split_10_part9_processed.csv
# 🚀 Starte Datei: split_11_part1.csv
# ✅ Gespeichert: results/split_10_part1_processed.csv
# 🚀 Starte Datei: split_10_part10.csv
# ✅ Gespeichert: results/split_10_part4_processed.csv
# 🚀 Starte Datei: split_10_part5.csv
# ✅ Gespeichert: results/split_11_part18_processed.csv
# 🚀 Starte Datei: split_11_part19.csv
# ✅ Gespeichert: results/split_11_part13_processed.csv
# 🚀 Starte Datei: split_11_part14.csv
# ✅ Gespeichert: results/split_13_part9_processed.csv
# 🚀 Starte Datei: split_14_part1.csv
# ✅ Gespeichert: results/split_13_part12_processed.csv
# 🚀 Starte Datei: split_13_part13.csv
# ✅ Gespeichert: results/split_11_part19_processed.csv
# 🚀 Starte Datei: split_11_part2.csv
# ✅ Gespeichert: results/split_10_part15_processed.csv
# 🚀 Starte Datei: split_10_part16.csv
# ✅ Gespeichert: results/split_14_part13_processed.csv
# 🚀 Starte Datei: split_14_part14.csv
# ✅ Gespeichert: results/split_12_part8_processed.csv
# 🚀 Starte Datei: split_12_part9.csv
# ✅ Gespeichert: results/split_10_part10_processed.csv
# 🚀 Starte Datei: split_10_part11.csv
# ✅ Gespeichert: results/split_12_part1_processed.csv
# 🚀 Starte Datei: split_12_part10.csv
# ✅ Gespeichert: results/split_12_part3_processed.csv
# 🚀 Starte Datei: split_12_part4.csv
# ✅ Gespeichert: results/split_14_part14_processed.csv
# 🚀 Starte Datei: split_14_part2.csv
# ✅ Gespeichert: results/split_11_part1_processed.csv
# 🚀 Starte Datei: split_11_part10.csv
# ✅ Gespeichert: results/split_10_part16_processed.csv
# 🚀 Starte Datei: split_10_part2.csv
# ✅ Gespeichert: results/split_13_part4_processed.csv
# 🚀 Starte Datei: split_13_part5.csv
# ✅ Gespeichert: results/split_10_part5_processed.csv
# 🚀 Starte Datei: split_10_part6.csv
# ✅ Gespeichert: results/split_11_part5_processed.csv
# 🚀 Starte Datei: split_11_part6.csv
# ✅ Gespeichert: results/split_14_part5_processed.csv
# 🚀 Starte Datei: split_14_part6.csv
# ✅ Gespeichert: results/split_11_part14_processed.csv
# 🚀 Starte Datei: split_11_part15.csv
# ✅ Gespeichert: results/split_11_part10_processed.csv
# 🚀 Starte Datei: split_11_part11.csv
# ✅ Gespeichert: results/split_10_part11_processed.csv
# 🚀 Starte Datei: split_10_part12.csv
# ✅ Gespeichert: results/split_10_part2_processed.csv
# 🚀 Starte Datei: split_10_part3.csv
# ✅ Gespeichert: results/split_11_part2_processed.csv
# 🚀 Starte Datei: split_11_part3.csv
# ✅ Gespeichert: results/split_10_part6_processed.csv
# 🚀 Starte Datei: split_10_part7.csv
# ✅ Gespeichert: results/split_13_part13_processed.csv
# 🚀 Starte Datei: split_13_part14.csv
# ✅ Gespeichert: results/split_12_part9_processed.csv
# 🚀 Starte Datei: split_13_part1.csv
# ✅ Gespeichert: results/split_11_part15_processed.csv
# 🚀 Starte Datei: split_11_part16.csv
# ✅ Gespeichert: results/split_12_part10_processed.csv
# 🚀 Starte Datei: split_12_part11.csv
# ✅ Gespeichert: results/split_11_part11_processed.csv
# 🚀 Starte Datei: split_11_part12.csv
# ✅ Gespeichert: results/split_10_part12_processed.csv
# 🚀 Starte Datei: split_10_part13.csv
# ✅ Gespeichert: results/split_13_part14_processed.csv
# 🚀 Starte Datei: split_13_part2.csv
# ✅ Gespeichert: results/split_12_part4_processed.csv
# 🚀 Starte Datei: split_12_part5.csv
# ✅ Gespeichert: results/split_10_part3_processed.csv
# 🚀 Starte Datei: split_15_part1.csv
# ✅ Gespeichert: results/split_13_part5_processed.csv
# 🚀 Starte Datei: split_13_part6.csv
# ✅ Gespeichert: results/split_14_part1_processed.csv
# 🚀 Starte Datei: split_14_part10.csv
# ✅ Gespeichert: results/split_10_part7_processed.csv
# 🚀 Starte Datei: split_10_part8.csv
# ✅ Gespeichert: results/split_11_part6_processed.csv
# 🚀 Starte Datei: split_11_part7.csv
# ✅ Gespeichert: results/split_10_part13_processed.csv
# 🚀 Starte Datei: split_15_part14.csv
# ✅ Gespeichert: results/split_11_part16_processed.csv
# 🚀 Starte Datei: split_11_part17.csv
# ✅ Gespeichert: results/split_11_part12_processed.csv
# 🚀 Starte Datei: split_15_part2.csv
# ✅ Gespeichert: results/split_11_part3_processed.csv
# 🚀 Starte Datei: split_11_part4.csv
# ✅ Gespeichert: results/split_10_part8_processed.csv
# 🚀 Starte Datei: split_15_part7.csv
# ✅ Gespeichert: results/split_13_part1_processed.csv
# 🚀 Starte Datei: split_13_part10.csv
# ✅ Gespeichert: results/split_14_part2_processed.csv
# 🚀 Starte Datei: split_14_part3.csv
# ✅ Gespeichert: results/split_12_part11_processed.csv
# 🚀 Starte Datei: split_12_part12.csv
# ✅ Gespeichert: results/split_15_part1_processed.csv
# 🚀 Starte Datei: split_15_part10.csv
# ✅ Gespeichert: results/split_14_part6_processed.csv
# 🚀 Starte Datei: split_14_part7.csv
# ✅ Gespeichert: results/split_13_part2_processed.csv
# 🚀 Starte Datei: split_13_part3.csv
# ✅ Gespeichert: results/split_12_part5_processed.csv
# 🚀 Starte Datei: split_12_part6.csv
# ✅ Gespeichert: results/split_11_part17_processed.csv
# 🚀 Starte Datei: split_1_part11.csv
# ✅ Gespeichert: results/split_13_part6_processed.csv
# 🚀 Starte Datei: split_13_part7.csv
# ✅ Gespeichert: results/split_15_part2_processed.csv
# 🚀 Starte Datei: split_15_part3.csv
# ✅ Gespeichert: results/split_14_part10_processed.csv
# 🚀 Starte Datei: split_14_part11.csv
# ✅ Gespeichert: results/split_15_part14_processed.csv
# 🚀 Starte Datei: split_15_part15.csv
# ✅ Gespeichert: results/split_11_part7_processed.csv
# 🚀 Starte Datei: split_11_part8.csv
# ✅ Gespeichert: results/split_13_part10_processed.csv
# 🚀 Starte Datei: split_13_part11.csv
# ✅ Gespeichert: results/split_12_part12_processed.csv
# 🚀 Starte Datei: split_12_part2.csv
# ✅ Gespeichert: results/split_1_part11_processed.csv
# 🚀 Starte Datei: split_1_part12.csv
# ✅ Gespeichert: results/split_11_part4_processed.csv
# 🚀 Starte Datei: split_1_part16.csv
# ✅ Gespeichert: results/split_13_part3_processed.csv
# 🚀 Starte Datei: split_1_part20.csv
# ✅ Gespeichert: results/split_1_part20_processed.csv
# 🚀 Starte Datei: split_1_part3.csv
# ✅ Gespeichert: results/split_15_part10_processed.csv
# 🚀 Starte Datei: split_15_part11.csv
# ✅ Gespeichert: results/split_15_part3_processed.csv
# 🚀 Starte Datei: split_15_part4.csv
# ✅ Gespeichert: results/split_14_part7_processed.csv
# 🚀 Starte Datei: split_14_part8.csv
# ✅ Gespeichert: results/split_1_part12_processed.csv
# 🚀 Starte Datei: split_1_part13.csv
# ✅ Gespeichert: results/split_1_part16_processed.csv
# 🚀 Starte Datei: split_1_part17.csv
# ✅ Gespeichert: results/split_12_part6_processed.csv
# 🚀 Starte Datei: split_12_part7.csv
# ✅ Gespeichert: results/split_15_part7_processed.csv
# 🚀 Starte Datei: split_15_part8.csv
# ✅ Gespeichert: results/split_14_part3_processed.csv
# 🚀 Starte Datei: split_14_part4.csv
# ✅ Gespeichert: results/split_14_part11_processed.csv
# 🚀 Starte Datei: split_14_part12.csv
# ✅ Gespeichert: results/split_15_part15_processed.csv
# 🚀 Starte Datei: split_15_part16.csv
# ✅ Gespeichert: results/split_13_part11_processed.csv
# 🚀 Starte Datei: split_1_part7.csv
# ✅ Gespeichert: results/split_13_part7_processed.csv
# 🚀 Starte Datei: split_13_part8.csv
# ✅ Gespeichert: results/split_1_part3_processed.csv
# 🚀 Starte Datei: split_1_part4.csv
# ✅ Gespeichert: results/split_1_part13_processed.csv
# 🚀 Starte Datei: split_1_part14.csv
# ✅ Gespeichert: results/split_12_part2_processed.csv
# 🚀 Starte Datei: split_2_part11.csv
# ✅ Gespeichert: results/split_1_part17_processed.csv
# 🚀 Starte Datei: split_1_part18.csv
# ✅ Gespeichert: results/split_15_part4_processed.csv
# 🚀 Starte Datei: split_15_part5.csv
# ✅ Gespeichert: results/split_11_part8_processed.csv
# 🚀 Starte Datei: split_11_part9.csv
# ✅ Gespeichert: results/split_1_part7_processed.csv
# 🚀 Starte Datei: split_1_part8.csv
# ✅ Gespeichert: results/split_1_part4_processed.csv
# 🚀 Starte Datei: split_1_part5.csv
# ✅ Gespeichert: results/split_1_part14_processed.csv
# 🚀 Starte Datei: split_1_part15.csv
# ✅ Gespeichert: results/split_2_part11_processed.csv
# 🚀 Starte Datei: split_2_part12.csv
# ✅ Gespeichert: results/split_1_part18_processed.csv
# 🚀 Starte Datei: split_1_part19.csv
# ✅ Gespeichert: results/split_13_part8_processed.csv
# 🚀 Starte Datei: split_2_part16.csv
# ✅ Gespeichert: results/split_15_part16_processed.csv
# 🚀 Starte Datei: split_15_part17.csv
# ✅ Gespeichert: results/split_14_part12_processed.csv
# 🚀 Starte Datei: split_2_part3.csv
# ✅ Gespeichert: results/split_1_part8_processed.csv
# 🚀 Starte Datei: split_1_part9.csv
# ✅ Gespeichert: results/split_15_part5_processed.csv
# 🚀 Starte Datei: split_15_part6.csv
# ✅ Gespeichert: results/split_12_part7_processed.csv
# 🚀 Starte Datei: split_2_part8.csv
# ✅ Gespeichert: results/split_1_part5_processed.csv
# 🚀 Starte Datei: split_1_part6.csv
# ✅ Gespeichert: results/split_15_part11_processed.csv
# 🚀 Starte Datei: split_15_part12.csv
# ✅ Gespeichert: results/split_1_part19_processed.csv
# 🚀 Starte Datei: split_1_part2.csv
# ✅ Gespeichert: results/split_2_part12_processed.csv
# 🚀 Starte Datei: split_2_part13.csv
# ✅ Gespeichert: results/split_1_part15_processed.csv
# 🚀 Starte Datei: split_3_part12.csv
# ✅ Gespeichert: results/split_2_part16_processed.csv
# 🚀 Starte Datei: split_2_part17.csv
# ✅ Gespeichert: results/split_11_part9_processed.csv
# 🚀 Starte Datei: split_3_part17.csv
# ✅ Gespeichert: results/split_1_part9_processed.csv
# 🚀 Starte Datei: split_2_part1.csv
# ✅ Gespeichert: results/split_2_part3_processed.csv
# 🚀 Starte Datei: split_2_part4.csv
# ✅ Gespeichert: results/split_14_part8_processed.csv
# 🚀 Starte Datei: split_14_part9.csv
# ✅ Gespeichert: results/split_15_part8_processed.csv
# 🚀 Starte Datei: split_15_part9.csv
# ✅ Gespeichert: results/split_2_part8_processed.csv
# 🚀 Starte Datei: split_2_part9.csv
# ✅ Gespeichert: results/split_14_part4_processed.csv
# 🚀 Starte Datei: split_3_part5.csv
# ✅ Gespeichert: results/split_2_part13_processed.csv
# 🚀 Starte Datei: split_2_part14.csv
# ✅ Gespeichert: results/split_1_part6_processed.csv
# 🚀 Starte Datei: split_4_part1.csv
# ✅ Gespeichert: results/split_3_part12_processed.csv
# 🚀 Starte Datei: split_3_part13.csv
# ✅ Gespeichert: results/split_1_part2_processed.csv
# 🚀 Starte Datei: split_4_part14.csv
# ✅ Gespeichert: results/split_15_part17_processed.csv
# 🚀 Starte Datei: split_15_part18.csv
# ✅ Gespeichert: results/split_15_part6_processed.csv
# 🚀 Starte Datei: split_4_part19.csv
# ✅ Gespeichert: results/split_2_part17_processed.csv
# 🚀 Starte Datei: split_2_part18.csv
# ✅ Gespeichert: results/split_3_part17_processed.csv
# 🚀 Starte Datei: split_3_part18.csv
# ✅ Gespeichert: results/split_2_part4_processed.csv
# 🚀 Starte Datei: split_2_part5.csv
# ✅ Gespeichert: results/split_2_part1_processed.csv
# 🚀 Starte Datei: split_2_part10.csv
# ✅ Gespeichert: results/split_2_part9_processed.csv
# 🚀 Starte Datei: split_3_part1.csv
# ✅ Gespeichert: results/split_15_part18_processed.csv
# 🚀 Starte Datei: split_4_part6.csv
# ✅ Gespeichert: results/split_4_part1_processed.csv
# 🚀 Starte Datei: split_4_part10.csv
# ✅ Gespeichert: results/split_2_part14_processed.csv
# 🚀 Starte Datei: split_2_part15.csv
# ✅ Gespeichert: results/split_3_part13_processed.csv
# 🚀 Starte Datei: split_3_part14.csv
# ✅ Gespeichert: results/split_3_part5_processed.csv
# 🚀 Starte Datei: split_3_part6.csv
# ✅ Gespeichert: results/split_3_part18_processed.csv
# 🚀 Starte Datei: split_3_part2.csv
# ✅ Gespeichert: results/split_2_part5_processed.csv
# 🚀 Starte Datei: split_2_part6.csv
# ✅ Gespeichert: results/split_2_part18_processed.csv
# 🚀 Starte Datei: split_2_part19.csv
# ✅ Gespeichert: results/split_2_part19_processed.csv
# 🚀 Starte Datei: split_2_part2.csv
# ✅ Gespeichert: results/split_2_part10_processed.csv
# 🚀 Starte Datei: split_5_part10.csv
# ✅ Gespeichert: results/split_4_part6_processed.csv
# 🚀 Starte Datei: split_4_part7.csv
# ✅ Gespeichert: results/split_3_part1_processed.csv
# 🚀 Starte Datei: split_3_part10.csv
# ✅ Gespeichert: results/split_4_part10_processed.csv
# 🚀 Starte Datei: split_4_part11.csv
# ✅ Gespeichert: results/split_3_part14_processed.csv
# 🚀 Starte Datei: split_3_part15.csv
# ✅ Gespeichert: results/split_2_part15_processed.csv
# 🚀 Starte Datei: split_5_part15.csv
# ✅ Gespeichert: results/split_4_part19_processed.csv
# 🚀 Starte Datei: split_4_part2.csv
# ✅ Gespeichert: results/split_15_part9_processed.csv
# 🚀 Starte Datei: split_1_part1.csv
# ✅ Gespeichert: results/split_15_part12_processed.csv
# 🚀 Starte Datei: split_15_part13.csv
# ✅ Gespeichert: results/split_3_part6_processed.csv
# 🚀 Starte Datei: split_3_part7.csv
# ✅ Gespeichert: results/split_2_part6_processed.csv
# 🚀 Starte Datei: split_2_part7.csv
# ✅ Gespeichert: results/split_3_part2_processed.csv
# 🚀 Starte Datei: split_3_part3.csv
# ✅ Gespeichert: results/split_2_part2_processed.csv
# 🚀 Starte Datei: split_5_part3.csv
# ✅ Gespeichert: results/split_14_part9_processed.csv
# 🚀 Starte Datei: split_5_part8.csv
# ✅ Gespeichert: results/split_5_part10_processed.csv
# 🚀 Starte Datei: split_5_part11.csv
# ✅ Gespeichert: results/split_4_part14_processed.csv
# 🚀 Starte Datei: split_4_part15.csv
# ✅ Gespeichert: results/split_5_part15_processed.csv
# 🚀 Starte Datei: split_5_part16.csv
# ✅ Gespeichert: results/split_4_part7_processed.csv
# 🚀 Starte Datei: split_4_part8.csv
# ✅ Gespeichert: results/split_4_part11_processed.csv
# 🚀 Starte Datei: split_4_part12.csv
# ✅ Gespeichert: results/split_3_part10_processed.csv
# 🚀 Starte Datei: split_3_part11.csv
# ✅ Gespeichert: results/split_3_part15_processed.csv
# 🚀 Starte Datei: split_3_part16.csv
# ✅ Gespeichert: results/split_4_part2_processed.csv
# 🚀 Starte Datei: split_4_part3.csv
# ✅ Gespeichert: results/split_4_part12_processed.csv
# 🚀 Starte Datei: split_4_part13.csv
# ✅ Gespeichert: results/split_2_part7_processed.csv
# 🚀 Starte Datei: split_6_part12.csv
# ✅ Gespeichert: results/split_1_part1_processed.csv
# 🚀 Starte Datei: split_1_part10.csv
# ✅ Gespeichert: results/split_3_part7_processed.csv
# 🚀 Starte Datei: split_3_part8.csv
# ✅ Gespeichert: results/split_3_part3_processed.csv
# 🚀 Starte Datei: split_3_part4.csv
# ✅ Gespeichert: results/split_5_part11_processed.csv
# 🚀 Starte Datei: split_5_part12.csv
# ✅ Gespeichert: results/split_4_part8_processed.csv
# 🚀 Starte Datei: split_4_part9.csv
# ✅ Gespeichert: results/split_5_part16_processed.csv
# 🚀 Starte Datei: split_5_part17.csv
# ✅ Gespeichert: results/split_3_part11_processed.csv
# 🚀 Starte Datei: split_6_part2.csv
# ✅ Gespeichert: results/split_5_part8_processed.csv
# 🚀 Starte Datei: split_5_part9.csv
# ✅ Gespeichert: results/split_5_part3_processed.csv
# 🚀 Starte Datei: split_5_part4.csv
# ✅ Gespeichert: results/split_4_part3_processed.csv
# 🚀 Starte Datei: split_4_part4.csv
# ✅ Gespeichert: results/split_3_part16_processed.csv
# 🚀 Starte Datei: split_6_part7.csv
# ✅ Gespeichert: results/split_1_part10_processed.csv
# 🚀 Starte Datei: split_7_part11.csv
# ✅ Gespeichert: results/split_6_part12_processed.csv
# 🚀 Starte Datei: split_6_part13.csv
# ✅ Gespeichert: results/split_15_part13_processed.csv
# 🚀 Starte Datei: split_7_part4.csv
# ✅ Gespeichert: results/split_3_part8_processed.csv
# 🚀 Starte Datei: split_3_part9.csv
# ✅ Gespeichert: results/split_3_part4_processed.csv
# 🚀 Starte Datei: split_7_part9.csv
# ✅ Gespeichert: results/split_4_part9_processed.csv
# 🚀 Starte Datei: split_5_part1.csv
# ✅ Gespeichert: results/split_5_part12_processed.csv
# 🚀 Starte Datei: split_5_part13.csv
# ✅ Gespeichert: results/split_5_part17_processed.csv
# 🚀 Starte Datei: split_5_part18.csv
# ✅ Gespeichert: results/split_7_part11_processed.csv
# 🚀 Starte Datei: split_7_part12.csv
# ✅ Gespeichert: results/split_4_part4_processed.csv
# 🚀 Starte Datei: split_4_part5.csv
# ✅ Gespeichert: results/split_6_part7_processed.csv
# 🚀 Starte Datei: split_6_part8.csv
# ✅ Gespeichert: results/split_6_part13_processed.csv
# 🚀 Starte Datei: split_6_part14.csv
# ✅ Gespeichert: results/split_5_part9_processed.csv
# 🚀 Starte Datei: split_6_part1.csv
# ✅ Gespeichert: results/split_6_part2_processed.csv
# 🚀 Starte Datei: split_6_part3.csv
# ✅ Gespeichert: results/split_4_part13_processed.csv
# 🚀 Starte Datei: split_8_part13.csv
# ✅ Gespeichert: results/split_4_part15_processed.csv
# 🚀 Starte Datei: split_4_part16.csv
# ✅ Gespeichert: results/split_5_part4_processed.csv
# 🚀 Starte Datei: split_5_part5.csv
# ✅ Gespeichert: results/split_5_part18_processed.csv
# 🚀 Starte Datei: split_5_part2.csv
# ✅ Gespeichert: results/split_3_part9_processed.csv
# 🚀 Starte Datei: split_8_part3.csv
# ✅ Gespeichert: results/split_7_part9_processed.csv
# 🚀 Starte Datei: split_8_part1.csv
# ✅ Gespeichert: results/split_7_part4_processed.csv
# 🚀 Starte Datei: split_7_part5.csv
# ✅ Gespeichert: results/split_5_part13_processed.csv
# 🚀 Starte Datei: split_5_part14.csv
# ✅ Gespeichert: results/split_7_part12_processed.csv
# 🚀 Starte Datei: split_7_part13.csv
# ✅ Gespeichert: results/split_4_part5_processed.csv
# 🚀 Starte Datei: split_8_part8.csv
# ✅ Gespeichert: results/split_6_part8_processed.csv
# 🚀 Starte Datei: split_6_part9.csv
# ✅ Gespeichert: results/split_6_part14_processed.csv
# 🚀 Starte Datei: split_6_part15.csv
# ✅ Gespeichert: results/split_6_part1_processed.csv
# 🚀 Starte Datei: split_6_part10.csv
# ✅ Gespeichert: results/split_8_part1_processed.csv
# 🚀 Starte Datei: split_8_part10.csv
# ✅ Gespeichert: results/split_8_part3_processed.csv
# 🚀 Starte Datei: split_8_part4.csv
# ✅ Gespeichert: results/split_5_part1_processed.csv
# 🚀 Starte Datei: split_9_part12.csv
# ✅ Gespeichert: results/split_7_part13_processed.csv
# 🚀 Starte Datei: split_7_part2.csv
# ✅ Gespeichert: results/split_8_part13_processed.csv
# 🚀 Starte Datei: split_8_part14.csv
# ✅ Gespeichert: results/split_5_part14_processed.csv
# 🚀 Starte Datei: split_9_part2.csv
# ✅ Gespeichert: results/split_6_part3_processed.csv
# 🚀 Starte Datei: split_6_part4.csv
# ✅ Gespeichert: results/split_7_part5_processed.csv
# 🚀 Starte Datei: split_7_part6.csv
# ✅ Gespeichert: results/split_5_part5_processed.csv
# 🚀 Starte Datei: split_5_part6.csv
# ✅ Gespeichert: results/split_6_part9_processed.csv
# 🚀 Starte Datei: split_7_part1.csv
# ✅ Gespeichert: results/split_6_part15_processed.csv
# 🚀 Starte Datei: split_6_part16.csv
# ✅ Gespeichert: results/split_5_part2_processed.csv
# 🚀 Starte Datei: split_9_part7.csv
# ✅ Gespeichert: results/split_6_part16_processed.csv
# ✅ Gespeichert: results/split_8_part8_processed.csv
# 🚀 Starte Datei: split_8_part9.csv
# ✅ Gespeichert: results/split_6_part10_processed.csv
# 🚀 Starte Datei: split_6_part11.csv
# ✅ Gespeichert: results/split_8_part4_processed.csv
# 🚀 Starte Datei: split_8_part5.csv
# ✅ Gespeichert: results/split_9_part12_processed.csv
# 🚀 Starte Datei: split_9_part13.csv
# ✅ Gespeichert: results/split_6_part4_processed.csv
# 🚀 Starte Datei: split_6_part5.csv
# ✅ Gespeichert: results/split_9_part2_processed.csv
# 🚀 Starte Datei: split_9_part3.csv
# ✅ Gespeichert: results/split_8_part10_processed.csv
# 🚀 Starte Datei: split_8_part11.csv
# ✅ Gespeichert: results/split_7_part2_processed.csv
# 🚀 Starte Datei: split_7_part3.csv
# ✅ Gespeichert: results/split_7_part6_processed.csv
# 🚀 Starte Datei: split_7_part7.csv
# ✅ Gespeichert: results/split_8_part14_processed.csv
# 🚀 Starte Datei: split_8_part15.csv
# ✅ Gespeichert: results/split_5_part6_processed.csv
# 🚀 Starte Datei: split_5_part7.csv
# ✅ Gespeichert: results/split_4_part16_processed.csv
# 🚀 Starte Datei: split_4_part17.csv
# ✅ Gespeichert: results/split_7_part1_processed.csv
# 🚀 Starte Datei: split_7_part10.csv
# ✅ Gespeichert: results/split_9_part7_processed.csv
# 🚀 Starte Datei: split_9_part8.csv
# ✅ Gespeichert: results/split_8_part5_processed.csv
# 🚀 Starte Datei: split_8_part6.csv
# ✅ Gespeichert: results/split_6_part11_processed.csv
# ✅ Gespeichert: results/split_8_part9_processed.csv
# 🚀 Starte Datei: split_9_part1.csv
# ✅ Gespeichert: results/split_9_part13_processed.csv
# 🚀 Starte Datei: split_9_part14.csv
# ✅ Gespeichert: results/split_6_part5_processed.csv
# 🚀 Starte Datei: split_6_part6.csv
# ✅ Gespeichert: results/split_7_part7_processed.csv
# 🚀 Starte Datei: split_7_part8.csv
# ✅ Gespeichert: results/split_9_part3_processed.csv
# 🚀 Starte Datei: split_9_part4.csv
# ✅ Gespeichert: results/split_7_part3_processed.csv
# ✅ Gespeichert: results/split_8_part15_processed.csv
# 🚀 Starte Datei: split_8_part16.csv
# ✅ Gespeichert: results/split_8_part11_processed.csv
# 🚀 Starte Datei: split_8_part12.csv
# ✅ Gespeichert: results/split_7_part10_processed.csv
# ✅ Gespeichert: results/split_8_part16_processed.csv
# 🚀 Starte Datei: split_8_part2.csv
# ✅ Gespeichert: results/split_8_part6_processed.csv
# 🚀 Starte Datei: split_8_part7.csv
# ✅ Gespeichert: results/split_9_part8_processed.csv
# 🚀 Starte Datei: split_9_part9.csv
# ✅ Gespeichert: results/split_5_part7_processed.csv
# ✅ Gespeichert: results/split_9_part1_processed.csv
# 🚀 Starte Datei: split_9_part10.csv
# ✅ Gespeichert: results/split_9_part14_processed.csv
# 🚀 Starte Datei: split_9_part15.csv
# ✅ Gespeichert: results/split_6_part6_processed.csv
# ✅ Gespeichert: results/split_7_part8_processed.csv
# ✅ Gespeichert: results/split_9_part4_processed.csv
# 🚀 Starte Datei: split_9_part5.csv
# ✅ Gespeichert: results/split_8_part2_processed.csv
# ✅ Gespeichert: results/split_8_part12_processed.csv
# ✅ Gespeichert: results/split_9_part9_processed.csv
# ✅ Gespeichert: results/split_4_part17_processed.csv
# 🚀 Starte Datei: split_4_part18.csv
# ✅ Gespeichert: results/split_8_part7_processed.csv
# ✅ Gespeichert: results/split_9_part10_processed.csv
# 🚀 Starte Datei: split_9_part11.csv
# ✅ Gespeichert: results/split_9_part15_processed.csv
# 🚀 Starte Datei: split_9_part16.csv
# ✅ Gespeichert: results/split_9_part5_processed.csv
# 🚀 Starte Datei: split_9_part6.csv
# ✅ Gespeichert: results/split_9_part16_processed.csv
# ✅ Gespeichert: results/split_9_part11_processed.csv
# ✅ Gespeichert: results/split_4_part18_processed.csv
# ✅ Gespeichert: results/split_9_part6_processed.csv
